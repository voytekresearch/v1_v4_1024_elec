# %% [markdown]
# ## Analyze periodic spectral params

# %% [markdown]
# ## Set-up

# %% [markdown]
# ### Imports

# %%
# Define paths

# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# custom
import sys
sys.path.append("../../code")
from paths import EXTERNAL_PATH, PROJECT_PATH
from info import SESSIONS
from plots import plot_schematic_var

# %% [markdown]
# ### Settings

# %%
# example sessions
SESSION = SESSIONS[0]

# %% [markdown]
# ### Load data

# %%
# load LFP spectral params results by bands
results = pd.read_csv(fr"{PROJECT_PATH}\data\results\lfp_spectral_params_bands.csv", index_col=0)

# %% [markdown]
# ### Compute stimulus-evoked change in periodic params

# %%
# split into two dataframes (enconding and baseline)
results_pre = results.loc[results["epoch"]=="pre"]
results_post = results.loc[results["epoch"]=="post"]

# %%
# merge two dataframes with suffixes for baseline and encoding
df_merge = results_post.merge(results_pre, on=['session','channel','chan_idx','array'], suffixes=['_post', '_pre'])
df_merge = df_merge.drop(columns=['epoch_pre','epoch_post'])

# compute difference
varname = ['offset', 'knee', 'exponent', 'r_squared', 'alpha_cf', 'alpha_bw', 'alpha_pw', 'beta_cf', 'beta_bw', 'beta_pw', 'gamma_cf', 'gamma_bw', 'gamma_pw']
for var in varname : 
    df_merge[f'{var}_diff'] = df_merge[f'{var}_post'] - df_merge[f'{var}_pre']

df_merge.head()
# Out:
#         session  channel  chan_idx  array  offset_post      knee_post  \
# 0  A_SNR_140819        0         0      1     9.902206  219236.318575
# 1  A_SNR_140819        1         1      1     9.889650  297544.240066
# 2  A_SNR_140819        2         2      1     8.637309   15271.606430
# 3  A_SNR_140819        3         3      1    10.169225  671155.781206
# 4  A_SNR_140819        4         4      1     9.680232  203919.954710
#
#    exponent_post  alpha_cf_post  alpha_pw_post  alpha_bw_post  ...  \
# 0       4.409639            NaN            NaN            NaN  ...
# 1       4.448360            NaN            NaN            NaN  ...
# 2       3.612422            NaN            NaN            NaN  ...
# 3       4.637297            NaN            NaN            NaN  ...
# 4       4.350254            NaN            NaN            NaN  ...
#
#    r_squared_diff  alpha_cf_diff  alpha_bw_diff  alpha_pw_diff  beta_cf_diff  \
# ...

# %%
# save results (overwrite spectral_params_bands.csv)
df_merge.to_csv(f'{EXTERNAL_PATH}/data/results/lfp_spectral_merged_bands.csv')

# %% [markdown]
# ### Plot

# %%
bands = ['alpha', 'beta', 'gamma']

# plot configuration
pos = [1, 2, 3]
label = ['cf', 'bw', 'pw']

for b in bands:
    # create dataframe for violin plot
    band_df = pd.DataFrame()
    band_df['cf'] = df_merge[f'{b}_cf_diff'].dropna()
    band_df['pw'] = df_merge[f'{b}_pw_diff'].dropna()
    band_df['bw'] = df_merge[f'{b}_bw_diff'].dropna()

    # plot
    fig, ax = plt.subplots()
    ax.violinplot(band_df)
    ax.set_title(f"\u0394 {b}")
    ax.set_xticks(pos)
    ax.set_xticklabels(label)
    ax.axhline(y=0, color='k', linestyle='--')
    plt.show()

    # save figure
    fig.savefig(fr"G:\Shared drives\v1_v4_1024\figures\periodic\{b}_diff.png")

# %%
# plot violin of both pre- and post- stimulus spectral params

colors = {'pre':'#fb8500', 'post':'#FF6F91'}

for band in ['alpha', 'beta', 'gamma']:
    for param, label in zip(['cf', 'pw', 'bw'], ['center frequency', 'relative power', 'bandwidth']):
        # plot
        fig, ax = plt.subplots()
        sns.violinplot(data=results, x="session", y=f"{band}_{param}", hue="epoch", palette=colors, split=True, inner='quarts', ax=ax)
        ax.set_title(f"{band} - {label}")
        ax.set_ylabel(label)

        # save figure
        fig.savefig(fr"{PROJECT_PATH}\figures\presentation_figs\{band}_{param}.png")

# %% [markdown]
# ### Spatial results for each subject/test day

# %%
# create directory figures
dir_figs = f"{EXTERNAL_PATH}/figures/params_schematic"
if not os.path.exists(dir_figs):
    os.makedirs(dir_figs)

# define odml file path (contains metadata including electrode positions)
odml_path = fr"{EXTERNAL_PATH}\data\dataset\{SESSION}\metadata_{SESSION}.odml"

# %%
for band in ['alpha', 'beta', 'gamma']:
    for param, label in zip(['cf', 'pw', 'bw'], ['center frequency', 'relative power', 'bandwidth']):
        print(f"Plotting {band} {label} schematic")
        plot_schematic_var(df_merge, odml_path, var=f'{band}_{param}', y_label=f'{band} {label}', dir_figs=f'{dir_figs}/{band}')
# Out:
# Plotting alpha center frequency schematic
#     plotting session (1/3): A_SNR_140819
# warning[None:5:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> inside <odML> tag
#  (line 5)
# warning[None:5:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> in odML document section <odML>  (line 5)
# ...
# Validation found 0 errors and 1 warnings in 0 Sections and 1 Properties.
# ...
# warning[None:5:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> inside <odML> tag
#  (line 5)
# warning[None:5:<{http://www.w3.org/1999/xsl/transform}stylesheet>]: Invalid element <{http://www.w3.org/1999/xsl/transform}stylesheet> in odML document section <odML>  (line 5)
# ...
